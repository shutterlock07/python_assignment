# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://code.datasciencedojo.com/datasciencedojo/datasets/raw/master/Online%20News%20Popularity/OnlineNewsPopularity.csv'

# %%
data = pd.read_csv(url)
data.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# ...

# %%
data.shape
# Out:
# (39644, 61)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             39644 non-null  object
#  1    timedelta                      39644 non-null  float64
#  2    n_tokens_title                 39644 non-null  float64
#  3    n_tokens_content               39644 non-null  float64
#  4    n_unique_tokens                39644 non-null  float64
#  5    n_non_stop_words               39644 non-null  float64
#  6    n_non_stop_unique_tokens       39644 non-null  float64
#  7    num_hrefs                      39644 non-null  float64
#  8    num_self_hrefs                 39644 non-null  float64
#  9    num_imgs                       39644 non-null  float64
#  10   num_videos                     39644 non-null  float64
#  11   average_token_length           39644 non-null  float64
# ...

# %%
data.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# ...

# %%
data.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
data.columns = data.columns.str.strip()

# %% [markdown]
# We will check of how the shares column is affected by the inpendent variable and explore

# %% [markdown]
# As the data is divided as:\
# number of words in title, content, unique, stop words, non-stop words\
# number of links, images, videos\
# length of content, numberof keywords\
# data chaneel = entertentertainment, bus, socmed, tech, world\
# day = monday, tuesday, wednesday, thursday, friday, saturday, sunday\
# is_weekend\
# topic is near = LDA [1,2,3,4,]\
# global = subjectivity, sentiment polarity, rate of positive words & negative words\

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data['shares'], bins=10, kde=True)
plt.xlabel('Shares')
plt.ylabel('Frequency')
plt.title('Distribution of Shares')
plt.show()

# %%
sns.pairplot(data[['shares', 'average_token_length', 'timedelta']])
plt.show()

# %%
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1220\2642049754.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
x = data[data['shares']<100000]

# %%
sns.boxplot(x=x.shares, width=0.8)
plt.xlabel('Shares')
plt.title('Box Plot of Shares')
plt.show()

# %%
size = data.groupby('is_weekend').size()
pie = plt.pie(size ,autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
weekdays = data.groupby(['weekday_is_monday', 'weekday_is_tuesday', 'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday', 'weekday_is_saturday', 'weekday_is_sunday']).size()

# %%
labels = ['weekday_is_monday', 'weekday_is_tuesday', 'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday', 'weekday_is_saturday', 'weekday_is_sunday']

# %%
pie = plt.pie(weekdays,autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.show()

# %% [markdown]
# We can see the significant change

# %%
channels = data.groupby(['data_channel_is_lifestyle','data_channel_is_entertainment', 'data_channel_is_bus', 'data_channel_is_socmed', 'data_channel_is_tech', 'data_channel_is_world']).size()

# %%
channel_labels = ['data_channel_is_lifestyle','data_channel_is_entertainment', 'data_channel_is_bus', 'data_channel_is_socmed', 'data_channel_is_tech', 'data_channel_is_world']

# %%
pie = plt.pie(channels,autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=channel_labels)
plt.show()

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
plt.style.use('ggplot')

fig = plt.figure(figsize = (10, 10)) ,


# Plot N Tokens in title
plt.subplot2grid(fig_dims, (0, 0))
data['n_tokens_title'].hist()
plt.title('N_tokens_title')

# Plot N Tokens content
plt.subplot2grid(fig_dims, (0, 1))
data['n_tokens_content'].hist(bins = 10, range = (0,3000))
plt.title('N_tokens_content')

# Plot N unique tokens 
plt.subplot2grid(fig_dims, (1, 0))
data['n_unique_tokens'].hist(bins = 10, range = (0,1))
plt.title('n_unique_tokens')

# Plot non stop words
plt.subplot2grid(fig_dims, (1, 1))
data['n_non_stop_words'].hist(bins = 10, range = (0,1))
plt.title('n_non_stop_words')

# Plot unique tokens
plt.subplot2grid(fig_dims, (2, 0))
data['n_non_stop_unique_tokens'].hist(bins = 10, range = (0,1))
plt.title('n_non_stop_unique_tokens'),
# Out:
# (Text(0.5, 1.0, 'n_non_stop_unique_tokens'),)

# %%
plt.style.use('ggplot')

fig = plt.figure(figsize = (10, 10)) 

# Plot number of links
plt.subplot2grid(fig_dims, (0, 0))
data['num_hrefs'].hist(range = (0,200))
plt.title('num_hrefs')

# Plot number of self links
plt.subplot2grid(fig_dims, (0, 1))
data['num_self_hrefs'].hist(bins = 10, range = (0,70))
plt.title('num_self_hrefs')

# Plot num of images
plt.subplot2grid(fig_dims, (1, 0))
data['num_imgs'].hist(bins = 10, range = (0,40))
plt.title('num_imgs')

# Plot number of videos
plt.subplot2grid(fig_dims, (1, 1))
data['num_videos'].hist(bins = 10, range = (0,30))
plt.title('num_videos')
# Out:
# Text(0.5, 1.0, 'num_videos')

# %%
LDA = ['LDA_00', 'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'shares']

sns.pairplot(data, vars=LDA, diag_kind='kde')

# %%
sns.scatterplot(x='n_tokens_content',y='shares', data=data)
# Out:
# <Axes: xlabel='n_tokens_content', ylabel='shares'>

# %%
sns.scatterplot(x='average_token_length',y='shares', data=data)
# Out:
# <Axes: xlabel='average_token_length', ylabel='shares'>

# %%
data[data['average_token_length']==0].shape
# Out:
# (1181, 61)

# %%
data[data['average_token_length']==0] = data['average_token_length'].mean()

# %%
data[data['n_unique_tokens']==0].shape
# Out:
# (0, 61)

# %%
data[data['n_unique_tokens']==0] = data['n_unique_tokens'].mean()

# %%
data.columns
# Out:
# Index(['url', 'timedelta', 'n_tokens_title', 'n_tokens_content',
#        'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens',
#        'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos',
#        'average_token_length', 'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
# ...

# %%
data = data.drop(['url', 'timedelta', 'data_channel_is_world', 'weekday_is_sunday'], axis=1)

# %%
X= data.drop(['shares'], axis=1)
y=data['shares']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
X_train_org, X_test_org, y_train_org, y_test_org = train_test_split(X,y, random_state = 0)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)

# %% [markdown]
# # KNN

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor

param_grid = {'n_neighbors': np.arange(1,30,1)}

grid_search = GridSearchCV(KNeighborsRegressor(), param_grid, cv=5, return_train_score=True)

# %%
grid_search.fit(X_train, y_train)

# %%
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Best parameters: {'n_neighbors': 29}
# Best cross-validation score: -0.03

# %%
knn = KNeighborsRegressor(n_neighbors = 28)
knn.fit(X_train, y_train)
print('Train score : ', knn.score(X_train, y_train))
print('Test score : ', knn.score(X_test, y_test))
# Out:
# Train score :  0.061426694128178694
# Test score :  0.00045511985934720833

# %%
y_pred = knn.predict(X_test)

# %% [markdown]
# # Random Forest Regressor

# %%
20+30
